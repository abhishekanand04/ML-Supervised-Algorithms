# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekanand04/ML-Supervised-Algorithms/blob/supervised-alogorithm/Entropy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

p1 = 0.6
p2 = 0.4
entropy = - (p1 * math.log2(p1) + p2 * math.log2(p2) )
entropy
# Out:
# 0.9709505944546686

# %%
import math

p1 = 5/7
p2 = 2/7
entropy = - (p1 * math.log2(p1) + p2 * math.log2(p2) )
entropy
# Out:
# 0.863120568566631

# %%
import math

p1 = 10/30
p2 = 20/30
entropy = - (p1 * math.log2(p1) + p2 * math.log2(p2) )
entropy
# Out:
# 0.9182958340544896

# %%
import math

p1 = 50/60
p2 = 10/60
entropy = - (p1 * math.log2(p1) + p2 * math.log2(p2) )
entropy
# Out:
# 0.6500224216483541

# %%
import math

p1 = 10/40
p2 = 30/40
entropy = - (p1 * math.log2(p1) + p2 * math.log2(p2) )
entropy
# Out:
# 0.8112781244591328

# %%
# Out:
# 1.0

# %%
p1 = 1/6
p2 = 5/6
gini = 1- ( p1**2 + p2**2  )
gini
# Out:
# 0.2777777777777777

# %%
import numpy as np
A = np.array([25,30,35,45,60])
mean = np.mean(A)
std = np.std(A)

# %%
(A - mean)/std
# Out:
# array([-1.12815215, -0.72524067, -0.32232919,  0.48349378,  1.69222822])
